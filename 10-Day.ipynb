# %%
#importing pandas
import pandas as pd
import seaborn as sns

# %%
#seaborn datasets
data=sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#exporting datasets
data.to_csv('titanic.xlsx')

# %%
df=pd.read_csv('train_and_test2.csv')
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
#heads
df.head(11)
# Out:
#     Passengerid   Age     Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0             1  22.0   7.2500    0      1     0       0       0       0
# 1             2  38.0  71.2833    1      1     0       0       0       0
# 2             3  26.0   7.9250    1      0     0       0       0       0
# 3             4  35.0  53.1000    1      1     0       0       0       0
# 4             5  35.0   8.0500    0      0     0       0       0       0
# 5             6  28.0   8.4583    0      0     0       0       0       0
# 6             7  54.0  51.8625    0      0     0       0       0       0
# 7             8   2.0  21.0750    0      3     0       0       0       0
# 8             9  27.0  11.1333    1      0     0       0       0       0
# 9            10  14.0  30.0708    1      1     0       0       0       0
# 10           11   4.0  16.7000    1      1     0       0       0       0
#
#     zero.4  ...  zero.12  zero.13  zero.14  Pclass  zero.15  zero.16  \
# ...

# %%
#tails
df.tail(25)
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 1284         1285  47.0   10.5000    0      0     0       0       0       0
# 1285         1286  29.0   22.0250    0      3     0       0       0       0
# 1286         1287  18.0   60.0000    1      1     0       0       0       0
# 1287         1288  24.0    7.2500    0      0     0       0       0       0
# 1288         1289  48.0   79.2000    1      1     0       0       0       0
# 1289         1290  22.0    7.7750    0      0     0       0       0       0
# 1290         1291  31.0    7.7333    0      0     0       0       0       0
# 1291         1292  30.0  164.8667    1      0     0       0       0       0
# 1292         1293  38.0   21.0000    0      1     0       0       0       0
# 1293         1294  22.0   59.4000    1      0     0       0       0       0
# 1294         1295  17.0   47.1000    0      0     0       0       0       0
# ...
